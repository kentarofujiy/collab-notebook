# %% [markdown]
# # Talking Head(?) Anime from a Single Image 3: Now the Body Too (Manual Poser Tool)
#
# **Instruction**
#
# 1. Run the four cells below, one by one, in order by clicking the "Play" button to the left of it. Wait for each cell to finish before going to the next one.
# 2. Scroll down to the end of the last cell, and play with the GUI.
#
# **Links**
#
# * Github repository: http://github.com/pkhungurn/talking-head-anime-3-demo
# * Project writeup: http://pkhungurn.github.io/talking-head-anime-3/

# %%
# Clone the repository
# %cd /content
# !git clone https://github.com/pkhungurn/talking-head-anime-3-demo.git
# Out:
# /content
# Cloning into 'talking-head-anime-3-demo'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 134 (delta 18), reused 13 (delta 13), pack-reused 110 (from 1)
# Receiving objects: 100% (134/134), 1.62 MiB | 30.14 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# CD into the repository directory.
# %cd /content/talking-head-anime-3-demo
# Out:
# /content/talking-head-anime-3-demo

# %%
# Download model files
# !mkdir -p data/models/standard_float
# !wget -O data/models/standard_float/editor.pt https://www.dropbox.com/s/zp3e5ox57sdws3y/editor.pt?dl=0
# !wget -O data/models/standard_float/eyebrow_decomposer.pt https://www.dropbox.com/s/bcp42knbrk7egk8/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/standard_float/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/oywaiio2s53lc57/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/standard_float/face_morpher.pt https://www.dropbox.com/s/8qvo0u5lw7hqvtq/face_morpher.pt?dl=0
# !wget -O data/models/standard_float/two_algo_face_body_rotator.pt https://www.dropbox.com/s/qmq1dnxrmzsxb4h/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/standard_half
# !wget -O data/models/standard_half/editor.pt https://www.dropbox.com/s/g21ps8gfuvz4kbo/editor.pt?dl=0
# !wget -O data/models/standard_half/eyebrow_decomposer.pt https://www.dropbox.com/s/nwwwevzpmxiilgn/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/standard_half/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/z5v0amgqif7yup1/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/standard_half/face_morpher.pt https://www.dropbox.com/s/g03sfnd5yfs0m65/face_morpher.pt?dl=0
# !wget -O data/models/standard_half/two_algo_face_body_rotator.pt https://www.dropbox.com/s/c5lrn7z34x12317/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/separable_float
# !wget -O data/models/separable_float/editor.pt https://www.dropbox.com/s/nwdxhrpa9fy19r4/editor.pt?dl=0
# !wget -O data/models/separable_float/eyebrow_decomposer.pt https://www.dropbox.com/s/hfzjcu9cqr9wm3i/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/separable_float/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/g04dyyyavh5o1e2/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_float/face_morpher.pt https://www.dropbox.com/s/vgi9dsj95y0rrwv/face_morpher.pt?dl=0
# !wget -O data/models/separable_float/two_algo_face_body_rotator.pt https://www.dropbox.com/s/8u0qond8po34l24/two_algo_face_body_rotator.pt?dl=0

# !mkdir -p data/models/separable_half
# !wget -O data/models/separable_half/editor.pt https://www.dropbox.com/s/on8kn6z9fj95j0h/editor.pt?dl=0
# !wget -O data/models/separable_half/eyebrow_decomposer.pt https://www.dropbox.com/s/0hxu8opu1hmghqe/eyebrow_decomposer.pt?dl=0
# !wget -O data/models/separable_half/eyebrow_morphing_combiner.pt https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_half/face_morpher.pt https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# !wget -O data/models/separable_half/two_algo_face_body_rotator.pt https://www.dropbox.com/s/vr8h2xxltszhw7w/two_algo_face_body_rotator.pt?dl=0
# Out:
# --2024-09-21 20:49:06--  https://www.dropbox.com/s/zp3e5ox57sdws3y/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/o3b874e1yxh959qtemec6/editor.pt?rlkey=9nuoudpgvrv5b2u3uw420l8gh&dl=0 [following]
# --2024-09-21 20:49:06--  https://www.dropbox.com/scl/fi/o3b874e1yxh959qtemec6/editor.pt?rlkey=9nuoudpgvrv5b2u3uw420l8gh&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com/cd/0/inline/CbAlCgII4Z3sStnuMZapjNo_s0QQPGSvfwBnzpXNYlOBnoSebsDLw-ojPvx_LjOLg1070iySI9Ldfhj6dOZG50ZG0eN0mbT89S8M4VnqG20NxOhQ1QxdzEw3gYnrzQNXUh0/file# [following]
# --2024-09-21 20:49:08--  https://uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com/cd/0/inline/CbAlCgII4Z3sStnuMZapjNo_s0QQPGSvfwBnzpXNYlOBnoSebsDLw-ojPvx_LjOLg1070iySI9Ldfhj6dOZG50ZG0eN0mbT89S8M4VnqG20NxOhQ1QxdzEw3gYnrzQNXUh0/file
# Resolving uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com (uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com (uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbDPQxGfxC6ak7DD4qVwwnQXwEUH7Y_6IyA7MpKOTAdSsAamse4FpX4d4BqgxcnCewrTRHMCmZ-MzukTXmcFTjmIwebwwFnAVq5h3hzapqlBpW0Sgptn7aLRB3VA11QbrA_qxFq-H3T9mhG-usY_uM4TmLwmpwGx3MiIgyAr0W_a1Bqz816xBfm4iPuAGVwHWhpNfqAK0AurROf1m5MEvlc37xF20s3y1k76BdgZCBDVgl2ETdcU1-k1bmOiBRLtdNfAMa-fnc8zH74U6wNDtR8K634pq0iAFkXt4eLs6IPmoVJ52iS5xndIOYr2sq0BpRIq6df5qi1ZrUUp15BsnTWtuQY-E23iSymGtBKUR6O-Dw/file [following]
# --2024-09-21 20:49:08--  https://uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com/cd/0/inline2/CbDPQxGfxC6ak7DD4qVwwnQXwEUH7Y_6IyA7MpKOTAdSsAamse4FpX4d4BqgxcnCewrTRHMCmZ-MzukTXmcFTjmIwebwwFnAVq5h3hzapqlBpW0Sgptn7aLRB3VA11QbrA_qxFq-H3T9mhG-usY_uM4TmLwmpwGx3MiIgyAr0W_a1Bqz816xBfm4iPuAGVwHWhpNfqAK0AurROf1m5MEvlc37xF20s3y1k76BdgZCBDVgl2ETdcU1-k1bmOiBRLtdNfAMa-fnc8zH74U6wNDtR8K634pq0iAFkXt4eLs6IPmoVJ52iS5xndIOYr2sq0BpRIq6df5qi1ZrUUp15BsnTWtuQY-E23iSymGtBKUR6O-Dw/file
# Reusing existing connection to uce17bc08506a9e8a979eff1aea8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 33471839 (32M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/editor.pt’
#
# data/models/standar 100%[===================>]  31.92M  16.8MB/s    in 1.9s
#
# 2024-09-21 20:49:11 (16.8 MB/s) - ‘data/models/standard_float/editor.pt’ saved [33471839/33471839]
#
# --2024-09-21 20:49:11--  https://www.dropbox.com/s/bcp42knbrk7egk8/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/b1lpiqotfnfprjzvmjr39/eyebrow_decomposer.pt?rlkey=2ln7c5s6ij0xqgtnmnj63wv8d&dl=0 [following]
# --2024-09-21 20:49:11--  https://www.dropbox.com/scl/fi/b1lpiqotfnfprjzvmjr39/eyebrow_decomposer.pt?rlkey=2ln7c5s6ij0xqgtnmnj63wv8d&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com/cd/0/inline/CbCqHtb4j15byCiAgjdMD0cNhK6fWw9LQyq31ePhPvhhsGR-bugBWioDRSCqSxy-FwXHku9y1gH2kwfiO7VDiXVuCn9ZkKs288uHiAydD3FQkgyKTljuSBR8Yz37TDIMel8/file# [following]
# --2024-09-21 20:49:12--  https://uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com/cd/0/inline/CbCqHtb4j15byCiAgjdMD0cNhK6fWw9LQyq31ePhPvhhsGR-bugBWioDRSCqSxy-FwXHku9y1gH2kwfiO7VDiXVuCn9ZkKs288uHiAydD3FQkgyKTljuSBR8Yz37TDIMel8/file
# Resolving uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com (uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6035:15::a27d:550f
# Connecting to uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com (uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbB-005N_5SuWFsYBx1LLHYX5SNVwVPuDY_FGew-5eKfxV8AqCv--G4CYWZrUv88VM44xX_HMBP_r5c-j0xGB7xxGC7FpebT8WBjOPwyh4YO6lNe1SvP1rFZsREp8l0LMoHs_8IJR5E-XznA0-VPR-fWr31kBQxrWGU_6Ta2LNdMYUt23xkosCZoULIM2SFY3HOHinKUEz94xoykZGMrRx_KX6PI3HKfavHW1E9mqjTwc-FmMUXglxzFxxxGuzZRQ1t9L18qd9iXVT0RFvoO6-UrwdfhLoLuZrddHh-Z2W3wbmtsypukYA2KumlX7YBghed4KjahFi49ybdWmhZ5FEMMpuKlVepKDTI57RpW6p82Ww/file [following]
# --2024-09-21 20:49:13--  https://uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com/cd/0/inline2/CbB-005N_5SuWFsYBx1LLHYX5SNVwVPuDY_FGew-5eKfxV8AqCv--G4CYWZrUv88VM44xX_HMBP_r5c-j0xGB7xxGC7FpebT8WBjOPwyh4YO6lNe1SvP1rFZsREp8l0LMoHs_8IJR5E-XznA0-VPR-fWr31kBQxrWGU_6Ta2LNdMYUt23xkosCZoULIM2SFY3HOHinKUEz94xoykZGMrRx_KX6PI3HKfavHW1E9mqjTwc-FmMUXglxzFxxxGuzZRQ1t9L18qd9iXVT0RFvoO6-UrwdfhLoLuZrddHh-Z2W3wbmtsypukYA2KumlX7YBghed4KjahFi49ybdWmhZ5FEMMpuKlVepKDTI57RpW6p82Ww/file
# Reusing existing connection to uc7166525b73a52fb56dfea428f2.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 125942879 (120M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/eyebrow_decomposer.pt’
#
# data/models/standar 100%[===================>] 120.11M  15.3MB/s    in 7.8s
#
# 2024-09-21 20:49:22 (15.3 MB/s) - ‘data/models/standard_float/eyebrow_decomposer.pt’ saved [125942879/125942879]
#
# --2024-09-21 20:49:22--  https://www.dropbox.com/s/oywaiio2s53lc57/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/zsclsyc5loscbaqmk1512/eyebrow_morphing_combiner.pt?rlkey=3q21ob8w57x1gr6jedl7ge12o&dl=0 [following]
# --2024-09-21 20:49:22--  https://www.dropbox.com/scl/fi/zsclsyc5loscbaqmk1512/eyebrow_morphing_combiner.pt?rlkey=3q21ob8w57x1gr6jedl7ge12o&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com/cd/0/inline/CbCJEZzBb4n6dYBP4ugCFWJIutnZ-dsnec8f_Wmu1JZaEevxXmx4IXs4q_4gU8I9l_Yl_UcF2BlI2_RC_UAiqJ0VoAfsYaVZJKrdRvKkOtHT9jJptoZ9srWh-FrbG_zFses/file# [following]
# --2024-09-21 20:49:23--  https://uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com/cd/0/inline/CbCJEZzBb4n6dYBP4ugCFWJIutnZ-dsnec8f_Wmu1JZaEevxXmx4IXs4q_4gU8I9l_Yl_UcF2BlI2_RC_UAiqJ0VoAfsYaVZJKrdRvKkOtHT9jJptoZ9srWh-FrbG_zFses/file
# Resolving uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com (uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:601d:15::a27d:50f
# Connecting to uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com (uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbCcnTOokzifjvDjIPN5Md6TLpVnuLfEY83Cc81ESzYXCg4Sv691SuU42xbKKJwPz41ZjY7EdFuo7IE1bCqhUhN_8B2-z70h6b8SkV2NnxcAK96c05Qe96C4NRq55YbXoxvp-uTR8tYz_ar8c1pzwBTn7IKv7i-EAiRvyBCiMkZz-ECQK9eFbjcz4mKpZFOiyh8wCcNFB25HvqD9-Jy9PI4mWpgbJ3wmYuYWV6rFC7HkaMARpHX2-0vbf9ktuRl-iTI-Rp40Q9qi8Fc5OmOymRvw8BgVGjSAxGZ7hHeTgsI1Cakvq_tGSqgn_m_E0pLl8WsdUNpltyo8qBlxo4tJ5uQo2pHVOMlDkeUdPM-4ClmFtw/file [following]
# --2024-09-21 20:49:24--  https://uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com/cd/0/inline2/CbCcnTOokzifjvDjIPN5Md6TLpVnuLfEY83Cc81ESzYXCg4Sv691SuU42xbKKJwPz41ZjY7EdFuo7IE1bCqhUhN_8B2-z70h6b8SkV2NnxcAK96c05Qe96C4NRq55YbXoxvp-uTR8tYz_ar8c1pzwBTn7IKv7i-EAiRvyBCiMkZz-ECQK9eFbjcz4mKpZFOiyh8wCcNFB25HvqD9-Jy9PI4mWpgbJ3wmYuYWV6rFC7HkaMARpHX2-0vbf9ktuRl-iTI-Rp40Q9qi8Fc5OmOymRvw8BgVGjSAxGZ7hHeTgsI1Cakvq_tGSqgn_m_E0pLl8WsdUNpltyo8qBlxo4tJ5uQo2pHVOMlDkeUdPM-4ClmFtw/file
# Reusing existing connection to uc93f1d9b2829907f8594c6cf793.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126168279 (120M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/eyebrow_morphing_combiner.pt’
#
# data/models/standar 100%[===================>] 120.32M  16.1MB/s    in 9.0s
#
# 2024-09-21 20:49:35 (13.3 MB/s) - ‘data/models/standard_float/eyebrow_morphing_combiner.pt’ saved [126168279/126168279]
#
# --2024-09-21 20:49:35--  https://www.dropbox.com/s/8qvo0u5lw7hqvtq/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/6v8tnb69ukpkbif0i80tl/face_morpher.pt?rlkey=f2uzl39kv882beogkl34lk3lq&dl=0 [following]
# --2024-09-21 20:49:35--  https://www.dropbox.com/scl/fi/6v8tnb69ukpkbif0i80tl/face_morpher.pt?rlkey=f2uzl39kv882beogkl34lk3lq&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com/cd/0/inline/CbCBklFdQVvOmcwiaFPO7GMbmfyYDPPR6Z0tLnOP4f75-kXLFeiOCTGvPvd8YmSuMvTGt0w8E0KT01SJ9OWw25LGkABeby7sYgxtvJ8xXXFQWzmoFeLPJbLaNb-qLMEqrNc/file# [following]
# --2024-09-21 20:49:36--  https://uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com/cd/0/inline/CbCBklFdQVvOmcwiaFPO7GMbmfyYDPPR6Z0tLnOP4f75-kXLFeiOCTGvPvd8YmSuMvTGt0w8E0KT01SJ9OWw25LGkABeby7sYgxtvJ8xXXFQWzmoFeLPJbLaNb-qLMEqrNc/file
# Resolving uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com (uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com (uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbCXKryjf0ldaqp3vwfm0vhYLorN63BlRGQbxKZ1FFDJ-ptgY7u3qNjOONwXS0Gb5JlWTvynPdjofqXE--7NDf2j4mnyIUwNXB3k63EFH58EwSdqIAIJdq2JBx14ed8wj_QYmmoPwoppVoKLvQx9o9d1SN5DI0Ft5OaBZVsuojc3LWGPTs5BrgS6d5rVQzDAFcVLHissfngJf_BJJaWK-iPAIy-tlq0XjypMNL9at4cNYpchVqrmhcx_J3JylhjTEMK5JrgYEOwfmpgs3lem61tBWrcVh-4ypHWTd1dJ3qYkUcrqR3M3L_4oRwqNIdSzlvHgVkolkN5UNtlvw0-_CO7rnXjvmY2pBx49a0VunqdRxQ/file [following]
# --2024-09-21 20:49:37--  https://uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com/cd/0/inline2/CbCXKryjf0ldaqp3vwfm0vhYLorN63BlRGQbxKZ1FFDJ-ptgY7u3qNjOONwXS0Gb5JlWTvynPdjofqXE--7NDf2j4mnyIUwNXB3k63EFH58EwSdqIAIJdq2JBx14ed8wj_QYmmoPwoppVoKLvQx9o9d1SN5DI0Ft5OaBZVsuojc3LWGPTs5BrgS6d5rVQzDAFcVLHissfngJf_BJJaWK-iPAIy-tlq0XjypMNL9at4cNYpchVqrmhcx_J3JylhjTEMK5JrgYEOwfmpgs3lem61tBWrcVh-4ypHWTd1dJ3qYkUcrqR3M3L_4oRwqNIdSzlvHgVkolkN5UNtlvw0-_CO7rnXjvmY2pBx49a0VunqdRxQ/file
# Reusing existing connection to uc8e6e493fa75874fa94d3beb725.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126444711 (121M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/face_morpher.pt’
#
# data/models/standar 100%[===================>] 120.59M  15.4MB/s    in 7.9s
#
# 2024-09-21 20:49:45 (15.4 MB/s) - ‘data/models/standard_float/face_morpher.pt’ saved [126444711/126444711]
#
# --2024-09-21 20:49:46--  https://www.dropbox.com/s/qmq1dnxrmzsxb4h/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/2kla73670f0sz9c2s8nv1/two_algo_face_body_rotator.pt?rlkey=0qvgk6x0uefqyj3mmyhqm7q52&dl=0 [following]
# --2024-09-21 20:49:46--  https://www.dropbox.com/scl/fi/2kla73670f0sz9c2s8nv1/two_algo_face_body_rotator.pt?rlkey=0qvgk6x0uefqyj3mmyhqm7q52&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com/cd/0/inline/CbCaDQ7dtvsGr7aucoeYpvB0XDv5Z66nFP7DE00IhdHcG1oWus_bCiDiw-jS1FNfSQSAjhdeGfc-PInuo0sTeCE9TMOSVLQdpFvGgsFNAGuqzD6s1DxAKS3qYW_yNdNyiAA/file# [following]
# --2024-09-21 20:49:47--  https://uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com/cd/0/inline/CbCaDQ7dtvsGr7aucoeYpvB0XDv5Z66nFP7DE00IhdHcG1oWus_bCiDiw-jS1FNfSQSAjhdeGfc-PInuo0sTeCE9TMOSVLQdpFvGgsFNAGuqzD6s1DxAKS3qYW_yNdNyiAA/file
# Resolving uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com (uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com (uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbBNyVaVZ98-nNKfIpbg30YDF5QxiqtRzGQasMyVtRthUTl6J6E0KiFQ1y5g4Bn-_GZS3ardGePTMfogi7KIuijLjimCYYHrma0kEVDPJHsdnM4ePKUJV93oyHeFDitABX5e1qIdVl3GWNab2Kmds4JatKt8oBGJiDCdYOWkIHqLFEb_Nvnz9qGAX13f4JjFH9-CxVLIw3_vz85g9R2U4kRcc_hvd83IapDZVND_Xzl6kEuUVuFBMk4JyEK9smvNV41T6qvpxTYNy7IVncckn-oJiutlo22DzV3xQzNcoucAMNeF5i731atjJtzk0XxrnJ5t3kNb5cXsIxje59LOKVNQAa_Xy5IK6u_OP0IxAwhRMA/file [following]
# --2024-09-21 20:49:47--  https://uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com/cd/0/inline2/CbBNyVaVZ98-nNKfIpbg30YDF5QxiqtRzGQasMyVtRthUTl6J6E0KiFQ1y5g4Bn-_GZS3ardGePTMfogi7KIuijLjimCYYHrma0kEVDPJHsdnM4ePKUJV93oyHeFDitABX5e1qIdVl3GWNab2Kmds4JatKt8oBGJiDCdYOWkIHqLFEb_Nvnz9qGAX13f4JjFH9-CxVLIw3_vz85g9R2U4kRcc_hvd83IapDZVND_Xzl6kEuUVuFBMk4JyEK9smvNV41T6qvpxTYNy7IVncckn-oJiutlo22DzV3xQzNcoucAMNeF5i731atjJtzk0XxrnJ5t3kNb5cXsIxje59LOKVNQAa_Xy5IK6u_OP0IxAwhRMA/file
# Reusing existing connection to uc04beeedd71a694fede839f118f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 130675279 (125M) [application/octet-stream]
# Saving to: ‘data/models/standard_float/two_algo_face_body_rotator.pt’
#
# data/models/standar 100%[===================>] 124.62M  16.1MB/s    in 7.9s
#
# 2024-09-21 20:49:56 (15.8 MB/s) - ‘data/models/standard_float/two_algo_face_body_rotator.pt’ saved [130675279/130675279]
#
# --2024-09-21 20:49:56--  https://www.dropbox.com/s/g21ps8gfuvz4kbo/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/olle06rhj0hqn7cs7biql/editor.pt?rlkey=ztc45wuh149oedwe9gko3crkg&dl=0 [following]
# --2024-09-21 20:49:57--  https://www.dropbox.com/scl/fi/olle06rhj0hqn7cs7biql/editor.pt?rlkey=ztc45wuh149oedwe9gko3crkg&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com/cd/0/inline/CbDrPqhmdARv3Y_jzFwlrrYcyBZhlNt8CQQsjVnU-RVuWrX0Qxy-VWqld_-6ZMU6TkR05ovSTQU3WVPGfRbOHczIZjLk63Kao4RWnG7kr1Uq-at2FOBbwbWxibDH1Cc_nWE/file# [following]
# --2024-09-21 20:49:57--  https://uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com/cd/0/inline/CbDrPqhmdARv3Y_jzFwlrrYcyBZhlNt8CQQsjVnU-RVuWrX0Qxy-VWqld_-6ZMU6TkR05ovSTQU3WVPGfRbOHczIZjLk63Kao4RWnG7kr1Uq-at2FOBbwbWxibDH1Cc_nWE/file
# Resolving uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com (uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com (uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbAm0DdrL4dxRewgUjt4rpVTxajyBFJjfYaMQ3TXqQABS_4TDq-ggVov-0qo8TJVLII_XNsax4lnffNL7mu93JQpN1sibD9reY173CmGaBuR5r_VNTLLZClZDpWJFUOob40geskwTYZ0nwFURKxGTh_mRxe0pWNvlJiQv3KkFCCnhiDl2zYP7oEHdd1Fp0z68uBnOFcdXMbc_oB-LRjYcBELAqY7tYWcZvlIx8HUccGTXjJSAYZHxk0s08yfk6rKhtCMQg4dToBhyqvL9fCX4uZnGvsqpBPoAGHxYeseC93tpPtqGCDGy5EgaacAMAy1PDcPZJ8OUjgHIxhCZMI86EsV5GuuoXyhphiyjqrQXAUY6Q/file [following]
# --2024-09-21 20:49:58--  https://uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com/cd/0/inline2/CbAm0DdrL4dxRewgUjt4rpVTxajyBFJjfYaMQ3TXqQABS_4TDq-ggVov-0qo8TJVLII_XNsax4lnffNL7mu93JQpN1sibD9reY173CmGaBuR5r_VNTLLZClZDpWJFUOob40geskwTYZ0nwFURKxGTh_mRxe0pWNvlJiQv3KkFCCnhiDl2zYP7oEHdd1Fp0z68uBnOFcdXMbc_oB-LRjYcBELAqY7tYWcZvlIx8HUccGTXjJSAYZHxk0s08yfk6rKhtCMQg4dToBhyqvL9fCX4uZnGvsqpBPoAGHxYeseC93tpPtqGCDGy5EgaacAMAy1PDcPZJ8OUjgHIxhCZMI86EsV5GuuoXyhphiyjqrQXAUY6Q/file
# Reusing existing connection to uc3744ec0e65bb4de58d470d4625.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16748511 (16M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/editor.pt’
#
# data/models/standar 100%[===================>]  15.97M  18.6MB/s    in 0.9s
#
# 2024-09-21 20:49:59 (18.6 MB/s) - ‘data/models/standard_half/editor.pt’ saved [16748511/16748511]
#
# --2024-09-21 20:50:00--  https://www.dropbox.com/s/nwwwevzpmxiilgn/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/6zlnpomzioe9g7y2xc6ss/eyebrow_decomposer.pt?rlkey=oalxswjc5f01jyfvfbd4npuaf&dl=0 [following]
# --2024-09-21 20:50:00--  https://www.dropbox.com/scl/fi/6zlnpomzioe9g7y2xc6ss/eyebrow_decomposer.pt?rlkey=oalxswjc5f01jyfvfbd4npuaf&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com/cd/0/inline/CbDrg-MfE3mHJ9ZoqKmNNz1S2widClOVC81y_nbOvL_NpZPEu7wDoWSE2GkkGE04njAmRj7rdE0i6XS9NbFb-IV53p0QQjlms90uJdMh1JreZhrOXehZZBBy30hH8U79Xm0/file# [following]
# --2024-09-21 20:50:01--  https://uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com/cd/0/inline/CbDrg-MfE3mHJ9ZoqKmNNz1S2widClOVC81y_nbOvL_NpZPEu7wDoWSE2GkkGE04njAmRj7rdE0i6XS9NbFb-IV53p0QQjlms90uJdMh1JreZhrOXehZZBBy30hH8U79Xm0/file
# Resolving uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com (uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com (uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbD9T932D6uK72c9Ph-dKzW7lf6Er6NXhmaaPDFxegJ32NOLutOyOidzRbgejIJWseDCclT-de_qweXLq26gNd6hvmNDdiBF_4wgCJE6V3I3rj7Kqwgk5rnKBIyaar-EZpniLF3waCVAYP4ZxHF9Ek8x9OGJYwkio2FzqEFYqS0mmzMGVughyrVPRoRxNxEerTljU3rs2SnVvt-VZhCt5xo_iXF52jq5KFmnscHdVI8XRvlXTtzZvkZDwSRiVZd69UlWuv-Ug_d1r8rFF2ta18zYpk-p0omuE4ZUJD4BcGPBghIgbVqXaxL7zed_HLeCyzi6ZOZj7yhNzhIhdYPR0l8DEsPzHB9YdEL_H9HZTfZ8BA/file [following]
# --2024-09-21 20:50:01--  https://uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com/cd/0/inline2/CbD9T932D6uK72c9Ph-dKzW7lf6Er6NXhmaaPDFxegJ32NOLutOyOidzRbgejIJWseDCclT-de_qweXLq26gNd6hvmNDdiBF_4wgCJE6V3I3rj7Kqwgk5rnKBIyaar-EZpniLF3waCVAYP4ZxHF9Ek8x9OGJYwkio2FzqEFYqS0mmzMGVughyrVPRoRxNxEerTljU3rs2SnVvt-VZhCt5xo_iXF52jq5KFmnscHdVI8XRvlXTtzZvkZDwSRiVZd69UlWuv-Ug_d1r8rFF2ta18zYpk-p0omuE4ZUJD4BcGPBghIgbVqXaxL7zed_HLeCyzi6ZOZj7yhNzhIhdYPR0l8DEsPzHB9YdEL_H9HZTfZ8BA/file
# Reusing existing connection to uc1619af309978c5f679b0e7ea39.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 62984031 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/eyebrow_decomposer.pt’
#
# data/models/standar 100%[===================>]  60.07M  14.9MB/s    in 4.0s
#
# 2024-09-21 20:50:06 (14.9 MB/s) - ‘data/models/standard_half/eyebrow_decomposer.pt’ saved [62984031/62984031]
#
# --2024-09-21 20:50:06--  https://www.dropbox.com/s/z5v0amgqif7yup1/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/mbjyelhvaf4rx635pyjtf/eyebrow_morphing_combiner.pt?rlkey=ojyjetp5gevpsnmuac4tnneu1&dl=0 [following]
# --2024-09-21 20:50:06--  https://www.dropbox.com/scl/fi/mbjyelhvaf4rx635pyjtf/eyebrow_morphing_combiner.pt?rlkey=ojyjetp5gevpsnmuac4tnneu1&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com/cd/0/inline/CbCWxmTeEWKwoUqlYYmsaAoHxMYmmrFshMbMXM1NoNKeRRsvNaQWg1PSE_s4aTv-gtk0m1jDNI8JnBLvkivENL7HedzkDHH9aPmh2LO3gWGBSCaJMrw7MjNlRWyju360Cy4/file# [following]
# --2024-09-21 20:50:07--  https://uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com/cd/0/inline/CbCWxmTeEWKwoUqlYYmsaAoHxMYmmrFshMbMXM1NoNKeRRsvNaQWg1PSE_s4aTv-gtk0m1jDNI8JnBLvkivENL7HedzkDHH9aPmh2LO3gWGBSCaJMrw7MjNlRWyju360Cy4/file
# Resolving uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com (uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com (uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbDn205J3kwiDESIrFV-IGs1F19yZ8g05gI4mAh7-1lDs4kdYimU9ZATYTLuTjHuZvjDgBV3NeQffmTrYD_UNb7Ij2vlRqXaqtVvL8AtcgJrQzeDNTK_ruhCZXcrDlWOCH5OBuG5OYVdz6v4YJxM9eZ7eNR1wUIBSB7wjhP1sK-c25HXuvoioFCwrvYU-rQk9vbaUwfsxaTf8gcZ18xeEJCXuziOj94-qLH90j2oY4kfDsQZfNBiofZCIqShAW6qk7AZvftiYyXlFSL-DL94eIpSMIUEudUkfsJqvOcuUhW0h8cpH41yp8artnMMn_cvDqVCglNIxKYlqLH1TfoQt5GsLim-qt1yvcHRDHdygkdymA/file [following]
# --2024-09-21 20:50:08--  https://uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com/cd/0/inline2/CbDn205J3kwiDESIrFV-IGs1F19yZ8g05gI4mAh7-1lDs4kdYimU9ZATYTLuTjHuZvjDgBV3NeQffmTrYD_UNb7Ij2vlRqXaqtVvL8AtcgJrQzeDNTK_ruhCZXcrDlWOCH5OBuG5OYVdz6v4YJxM9eZ7eNR1wUIBSB7wjhP1sK-c25HXuvoioFCwrvYU-rQk9vbaUwfsxaTf8gcZ18xeEJCXuziOj94-qLH90j2oY4kfDsQZfNBiofZCIqShAW6qk7AZvftiYyXlFSL-DL94eIpSMIUEudUkfsJqvOcuUhW0h8cpH41yp8artnMMn_cvDqVCglNIxKYlqLH1TfoQt5GsLim-qt1yvcHRDHdygkdymA/file
# Reusing existing connection to uce6076289e2ee50cda50630a4b0.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63096535 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/eyebrow_morphing_combiner.pt’
#
# data/models/standar 100%[===================>]  60.17M  15.3MB/s    in 3.9s
#
# 2024-09-21 20:50:13 (15.3 MB/s) - ‘data/models/standard_half/eyebrow_morphing_combiner.pt’ saved [63096535/63096535]
#
# --2024-09-21 20:50:13--  https://www.dropbox.com/s/g03sfnd5yfs0m65/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/z2pn8sqe6x2lsx2rkaz4j/face_morpher.pt?rlkey=vg8m0a4yojho7ve1gx7xfd1jm&dl=0 [following]
# --2024-09-21 20:50:13--  https://www.dropbox.com/scl/fi/z2pn8sqe6x2lsx2rkaz4j/face_morpher.pt?rlkey=vg8m0a4yojho7ve1gx7xfd1jm&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com/cd/0/inline/CbCGP1mvhhc8oSNClw4rtQdojqL37Tc5tAMZupKCVMWly_S48lzpPLY2TyO8Xe-lzQ_y7y3Qp76uuW6h3uB7i1JnaiPf-yg9OiyKhQ0xAx6k-4BxgGDMCH-0PJfQvqP2PNs/file# [following]
# --2024-09-21 20:50:14--  https://ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com/cd/0/inline/CbCGP1mvhhc8oSNClw4rtQdojqL37Tc5tAMZupKCVMWly_S48lzpPLY2TyO8Xe-lzQ_y7y3Qp76uuW6h3uB7i1JnaiPf-yg9OiyKhQ0xAx6k-4BxgGDMCH-0PJfQvqP2PNs/file
# Resolving ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com (ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com (ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbCC1r-xhREJ1UEKY3bhYS9PXP6WIResx6lUu3ngGmOK5TtPaBu9gljt38KKKLuW8L9QoalCvlOnlptKBLrNO9G0rY7DnO9IaENarR3ZvNRCQNMJ_a0vkSN2yyVhejK55GHDSwM5YpVoi2qVEQQOfgCY_o-71krFam_C47Et26aQA3KsDJJQAWIYaXlo1YGV4Au4eNW96tkNMR-vQ312Tbxf-IPhwW0wSj-vilZOVcT41gWSIcHNRv7q1zw1sZD-PzXUTWHlvga7UGzP_ltXvjiHPH2EZP7gWnLNNXQilRhtMNz-NS_HvxyE3vw-IutkUAH-aGI7uK9MoThDIxzcrIkJJy1gY-rxvL50JDdWUcimCw/file [following]
# --2024-09-21 20:50:16--  https://ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com/cd/0/inline2/CbCC1r-xhREJ1UEKY3bhYS9PXP6WIResx6lUu3ngGmOK5TtPaBu9gljt38KKKLuW8L9QoalCvlOnlptKBLrNO9G0rY7DnO9IaENarR3ZvNRCQNMJ_a0vkSN2yyVhejK55GHDSwM5YpVoi2qVEQQOfgCY_o-71krFam_C47Et26aQA3KsDJJQAWIYaXlo1YGV4Au4eNW96tkNMR-vQ312Tbxf-IPhwW0wSj-vilZOVcT41gWSIcHNRv7q1zw1sZD-PzXUTWHlvga7UGzP_ltXvjiHPH2EZP7gWnLNNXQilRhtMNz-NS_HvxyE3vw-IutkUAH-aGI7uK9MoThDIxzcrIkJJy1gY-rxvL50JDdWUcimCw/file
# Reusing existing connection to ucfafb0c12136b355f758a29eff6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63234727 (60M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/face_morpher.pt’
#
# data/models/standar 100%[===================>]  60.30M  15.0MB/s    in 4.0s
#
# 2024-09-21 20:50:20 (15.0 MB/s) - ‘data/models/standard_half/face_morpher.pt’ saved [63234727/63234727]
#
# --2024-09-21 20:50:21--  https://www.dropbox.com/s/c5lrn7z34x12317/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/qgfw2ps6g7a8qbas6tw7x/two_algo_face_body_rotator.pt?rlkey=wpf33euhqzmh1vq5m1x07jya0&dl=0 [following]
# --2024-09-21 20:50:21--  https://www.dropbox.com/scl/fi/qgfw2ps6g7a8qbas6tw7x/two_algo_face_body_rotator.pt?rlkey=wpf33euhqzmh1vq5m1x07jya0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com/cd/0/inline/CbCOTGqp950cCLdfu47Mhq6dTL16vTBgo-BLBbgA0iqjHrw9b9K9-XKiU-4OppvTYbVZIyW59DNw9xodCDKBxYXhjIiBQu1jyUyDCzQAstKRrSBUox3yXUrhkg9cBTYltMk/file# [following]
# --2024-09-21 20:50:22--  https://uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com/cd/0/inline/CbCOTGqp950cCLdfu47Mhq6dTL16vTBgo-BLBbgA0iqjHrw9b9K9-XKiU-4OppvTYbVZIyW59DNw9xodCDKBxYXhjIiBQu1jyUyDCzQAstKRrSBUox3yXUrhkg9cBTYltMk/file
# Resolving uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com (uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com (uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbAX9va7l5TxUzoSHtHODCwtRyOoFRDpEXJVcYgo2Wou-58gbo7lYM6bORbfBubP187HAxoZl7xwOpsSkWYk90XIGebzbcPKBJQFJs9KwrJieAmVTeSijnNpIWEZETSgpN1jO96seA3MaBV1S9Z6fxxx1ejawSHWtbVE2q8LCC7wC2YhmHndsDvgVwJzmONRDI6eFTa1-qcjc6UoQE1UfwzQyvf0EnelqiSZSqgEHMwijaGwHUsChxNuG72Mgmh4AjMdg8sQTcJoq_-NUBHWKB3Uv86sRYbIRpKCYhvwIRpidO-769wOz2eN0lLdb1GJvLIVzrzzZceTxv1uLbgGyvt-SenaRwG_zLpezQOywXrmBA/file [following]
# --2024-09-21 20:50:23--  https://uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com/cd/0/inline2/CbAX9va7l5TxUzoSHtHODCwtRyOoFRDpEXJVcYgo2Wou-58gbo7lYM6bORbfBubP187HAxoZl7xwOpsSkWYk90XIGebzbcPKBJQFJs9KwrJieAmVTeSijnNpIWEZETSgpN1jO96seA3MaBV1S9Z6fxxx1ejawSHWtbVE2q8LCC7wC2YhmHndsDvgVwJzmONRDI6eFTa1-qcjc6UoQE1UfwzQyvf0EnelqiSZSqgEHMwijaGwHUsChxNuG72Mgmh4AjMdg8sQTcJoq_-NUBHWKB3Uv86sRYbIRpKCYhvwIRpidO-769wOz2eN0lLdb1GJvLIVzrzzZceTxv1uLbgGyvt-SenaRwG_zLpezQOywXrmBA/file
# Reusing existing connection to uc9cc45ca3d5d2d9a30b73f9d87f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65350735 (62M) [application/octet-stream]
# Saving to: ‘data/models/standard_half/two_algo_face_body_rotator.pt’
#
# data/models/standar 100%[===================>]  62.32M  14.2MB/s    in 4.4s
#
# 2024-09-21 20:50:28 (14.2 MB/s) - ‘data/models/standard_half/two_algo_face_body_rotator.pt’ saved [65350735/65350735]
#
# --2024-09-21 20:50:28--  https://www.dropbox.com/s/nwdxhrpa9fy19r4/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/bdqw1g2wig2g8jtup5ph0/editor.pt?rlkey=p18b39uk4u1cs0yoer2b4ckkn&dl=0 [following]
# --2024-09-21 20:50:29--  https://www.dropbox.com/scl/fi/bdqw1g2wig2g8jtup5ph0/editor.pt?rlkey=p18b39uk4u1cs0yoer2b4ckkn&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com/cd/0/inline/CbDou6aQgPTnzDksDT3UViPj4YwqpnKKtgeDKSBV0qnfKERsfkGuC71Nt33dIMMjEwTTlazXStBCyx-GzSUcMMKqYDde6YAT0csXv4nqdZ-82R3Za30SxkMM2RT5eGWYahc/file# [following]
# --2024-09-21 20:50:29--  https://uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com/cd/0/inline/CbDou6aQgPTnzDksDT3UViPj4YwqpnKKtgeDKSBV0qnfKERsfkGuC71Nt33dIMMjEwTTlazXStBCyx-GzSUcMMKqYDde6YAT0csXv4nqdZ-82R3Za30SxkMM2RT5eGWYahc/file
# Resolving uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com (uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com (uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbAup13D3NtA2YMQEGRcp3xPX0xRSeSkTR0w8CZALRNWDbgg3o5BcoewoFbHaKWbtNEElkcLTVzmena0izPFau2c3hymBUVUYn-UsEZW1fV64g0xESya0psEiCmwfi4EL0u4rhMrN0-CrAorz8fREZwBuGrwMpBnymZwINteBnWGT5vWStG4Zk18Hao0RVfAKBUKU8xUiMszYM7ZiwXfO90Q3BhCjht4XFGkLWNyaupQ1NKkV11BILN28SVOpp_maE9r6MXmozHz0qgApO-uEVJ-wb-K2WiHlPYJMEcKoiHvo-4ubYUEL4o76rCeLp2mIOu3h9gOGvuTjVz25GwYpyqcue7HMJArUMD16G0cGpCiZQ/file [following]
# --2024-09-21 20:50:31--  https://uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com/cd/0/inline2/CbAup13D3NtA2YMQEGRcp3xPX0xRSeSkTR0w8CZALRNWDbgg3o5BcoewoFbHaKWbtNEElkcLTVzmena0izPFau2c3hymBUVUYn-UsEZW1fV64g0xESya0psEiCmwfi4EL0u4rhMrN0-CrAorz8fREZwBuGrwMpBnymZwINteBnWGT5vWStG4Zk18Hao0RVfAKBUKU8xUiMszYM7ZiwXfO90Q3BhCjht4XFGkLWNyaupQ1NKkV11BILN28SVOpp_maE9r6MXmozHz0qgApO-uEVJ-wb-K2WiHlPYJMEcKoiHvo-4ubYUEL4o76rCeLp2mIOu3h9gOGvuTjVz25GwYpyqcue7HMJArUMD16G0cGpCiZQ/file
# Reusing existing connection to uc3eaca0ac079718ca17280e7b50.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3802999 (3.6M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/editor.pt’
#
# data/models/separab 100%[===================>]   3.63M  --.-KB/s    in 0.07s
#
# 2024-09-21 20:50:32 (48.9 MB/s) - ‘data/models/separable_float/editor.pt’ saved [3802999/3802999]
#
# --2024-09-21 20:50:32--  https://www.dropbox.com/s/hfzjcu9cqr9wm3i/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/qc01ia5t8k7efttzbcm58/eyebrow_decomposer.pt?rlkey=7c70ystu7oacvq7sz4dovwqtd&dl=0 [following]
# --2024-09-21 20:50:32--  https://www.dropbox.com/scl/fi/qc01ia5t8k7efttzbcm58/eyebrow_decomposer.pt?rlkey=7c70ystu7oacvq7sz4dovwqtd&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc472d01308744c758da554a6a05.dl.dropboxusercontent.com/cd/0/inline/CbCQ_0zPGIdD9j8LhHpTn3hHCqO2HwI_zO5Ab5cjhFx5QyBvJ9oVxz-E6Ei_KBkaF7LVr8J5jYEJSFAH7WBANFKNSSbptJffhPKqgAQj5y6iVEXqEC4XepZDPDH-fLlp4Xg/file# [following]
# --2024-09-21 20:50:33--  https://uc472d01308744c758da554a6a05.dl.dropboxusercontent.com/cd/0/inline/CbCQ_0zPGIdD9j8LhHpTn3hHCqO2HwI_zO5Ab5cjhFx5QyBvJ9oVxz-E6Ei_KBkaF7LVr8J5jYEJSFAH7WBANFKNSSbptJffhPKqgAQj5y6iVEXqEC4XepZDPDH-fLlp4Xg/file
# Resolving uc472d01308744c758da554a6a05.dl.dropboxusercontent.com (uc472d01308744c758da554a6a05.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc472d01308744c758da554a6a05.dl.dropboxusercontent.com (uc472d01308744c758da554a6a05.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbDuwV8FAQE6XmyPN7ivFMl935ihVHVtOQdMdAQbpYMGIdWNKMfycGe9dI3t0gHKIJBDoFPvAAL6kszUoUiV68tIIk7qjpuUaee1ob5fL33MbhilsjWg3tGYbCoGdQWlroM09LWPuANqalGMEPpZIwr66CFc-5V9ugBWTCCY0VsGgN3iLa78oVWDefHMpWUNOFGm9TNpwpylLucNHHixml0HQBbqbg1Qeh3XaIoZWhNOgbQoooS1-ppeNxP8H72FucHVMM32Oxh3wjee7nF0LACWO-WXVHFRmxgv03w-mcxdkPHg5IHDEHMvzMFjcX0ccEAjhtcVf0cBjhB4wN3zSiFw4LK4OvY9Mmtc1JJI81OJCg/file [following]
# --2024-09-21 20:50:34--  https://uc472d01308744c758da554a6a05.dl.dropboxusercontent.com/cd/0/inline2/CbDuwV8FAQE6XmyPN7ivFMl935ihVHVtOQdMdAQbpYMGIdWNKMfycGe9dI3t0gHKIJBDoFPvAAL6kszUoUiV68tIIk7qjpuUaee1ob5fL33MbhilsjWg3tGYbCoGdQWlroM09LWPuANqalGMEPpZIwr66CFc-5V9ugBWTCCY0VsGgN3iLa78oVWDefHMpWUNOFGm9TNpwpylLucNHHixml0HQBbqbg1Qeh3XaIoZWhNOgbQoooS1-ppeNxP8H72FucHVMM32Oxh3wjee7nF0LACWO-WXVHFRmxgv03w-mcxdkPHg5IHDEHMvzMFjcX0ccEAjhtcVf0cBjhB4wN3zSiFw4LK4OvY9Mmtc1JJI81OJCg/file
# Reusing existing connection to uc472d01308744c758da554a6a05.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13313007 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/eyebrow_decomposer.pt’
#
# data/models/separab 100%[===================>]  12.70M  15.8MB/s    in 0.8s
#
# 2024-09-21 20:50:35 (15.8 MB/s) - ‘data/models/separable_float/eyebrow_decomposer.pt’ saved [13313007/13313007]
#
# --2024-09-21 20:50:35--  https://www.dropbox.com/s/g04dyyyavh5o1e2/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/u59spi0326z8lcv91idfq/eyebrow_morphing_combiner.pt?rlkey=8wea2s6bfaa3tgevfc60q8q9t&dl=0 [following]
# --2024-09-21 20:50:36--  https://www.dropbox.com/scl/fi/u59spi0326z8lcv91idfq/eyebrow_morphing_combiner.pt?rlkey=8wea2s6bfaa3tgevfc60q8q9t&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com/cd/0/inline/CbCMevHhFiPCuNBumDeR1hUO30WPf5l4lotIQcVcdJxFmyQuyx9HrejBLVYxU8FpMigb1UvjMlJIeOvkgpmCyM0sj5M0B0X0kC9VU2GlpMZluGAehunRiVvtMsZ-fEsNnUM/file# [following]
# --2024-09-21 20:50:37--  https://uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com/cd/0/inline/CbCMevHhFiPCuNBumDeR1hUO30WPf5l4lotIQcVcdJxFmyQuyx9HrejBLVYxU8FpMigb1UvjMlJIeOvkgpmCyM0sj5M0B0X0kC9VU2GlpMZluGAehunRiVvtMsZ-fEsNnUM/file
# Resolving uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com (uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com (uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbB8TSwJ8MjEz9rQHzmwghR4BlW90sEghsHhb55PxcyCIjkVonGDnKMQv7vbue3FxNZpAGmbqswGO9kNg7LfHn88TgZoxSbfVl9I3nMW2KigmvWuleOyc8Ao7oo0MAkqCEtMiwm5ga4UUyiaaYjh9ttJtdmq-ky9ZCl_qTwKcrX4n37U8-Yyx-_qbF4EGkil5vKl2Qyk9brAHSGDxLxoV-KqN4APlbN6UkBNJNHMvt6wuCKhhueMDbZnzufRez45aJKIoNsQRmEtgWqSOabD48OU0SMhzyOTKMRBeBeEgtvthipuaxJLwnpcYAhTrQ1WYfpVb2DRiEuuvLpq_8eIiXRAK8t5NHdMLSZQOuoEaQlk1w/file [following]
# --2024-09-21 20:50:37--  https://uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com/cd/0/inline2/CbB8TSwJ8MjEz9rQHzmwghR4BlW90sEghsHhb55PxcyCIjkVonGDnKMQv7vbue3FxNZpAGmbqswGO9kNg7LfHn88TgZoxSbfVl9I3nMW2KigmvWuleOyc8Ao7oo0MAkqCEtMiwm5ga4UUyiaaYjh9ttJtdmq-ky9ZCl_qTwKcrX4n37U8-Yyx-_qbF4EGkil5vKl2Qyk9brAHSGDxLxoV-KqN4APlbN6UkBNJNHMvt6wuCKhhueMDbZnzufRez45aJKIoNsQRmEtgWqSOabD48OU0SMhzyOTKMRBeBeEgtvthipuaxJLwnpcYAhTrQ1WYfpVb2DRiEuuvLpq_8eIiXRAK8t5NHdMLSZQOuoEaQlk1w/file
# Reusing existing connection to uca85f06b7542fc7e070a7029ebf.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13334119 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/eyebrow_morphing_combiner.pt’
#
# data/models/separab 100%[===================>]  12.72M  15.9MB/s    in 0.8s
#
# 2024-09-21 20:50:39 (15.9 MB/s) - ‘data/models/separable_float/eyebrow_morphing_combiner.pt’ saved [13334119/13334119]
#
# --2024-09-21 20:50:39--  https://www.dropbox.com/s/vgi9dsj95y0rrwv/face_morpher.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/lmigcugjnm61xac95hdjk/face_morpher.pt?rlkey=fpn603hd1xdqbgrrwjb6knm5t&dl=0 [following]
# --2024-09-21 20:50:39--  https://www.dropbox.com/scl/fi/lmigcugjnm61xac95hdjk/face_morpher.pt?rlkey=fpn603hd1xdqbgrrwjb6knm5t&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com/cd/0/inline/CbDEZ3NFEjAg51UsyTSQEJ0-UIy8bncO79rrxHlEZ-bpXu12m1cI9QiMxuNkWnsHflvJERxVq9Z-vQ02qRdlizxUsO47n9jC8MsydvSbR9mWe3FxNsiG2pS8TOpeYGHjZ8c/file# [following]
# --2024-09-21 20:50:41--  https://uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com/cd/0/inline/CbDEZ3NFEjAg51UsyTSQEJ0-UIy8bncO79rrxHlEZ-bpXu12m1cI9QiMxuNkWnsHflvJERxVq9Z-vQ02qRdlizxUsO47n9jC8MsydvSbR9mWe3FxNsiG2pS8TOpeYGHjZ8c/file
# Resolving uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com (uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6031:15::a27d:510f
# Connecting to uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com (uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbBO2RY-SkIDjk9H7exq0LGueEwkg3DX3X_XEV5BhdWOzPNKxadVX4TT_24XhgHzMYR3ELutaGiQBPueB1u8djybQcVJSV0Oluh9mac4GEUopresY0eYXfxUEPP5z1ttondto05oh_Ll0jRzb3HpcbaaLVj4jvGCz5Rckw57y0viFtAgxG2BXEfTL5SqNhKFRzRFmF105VGU2i1kl_gzwKYwxVoGGiSX5qI5Ejr-Dr3KdR4t1VN-ZQHUDG5-jz14_NfIPbKJJ0313Olj9jb4Mxjk9VzfUnUPMQMlSCWdzqn4YigKvWQfUqWG8OvQmn8gvMcabI6LEjQLixwPcuFIUjEPSTM3T_HGs3NV-UK4Ayy4WQ/file [following]
# --2024-09-21 20:50:43--  https://uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com/cd/0/inline2/CbBO2RY-SkIDjk9H7exq0LGueEwkg3DX3X_XEV5BhdWOzPNKxadVX4TT_24XhgHzMYR3ELutaGiQBPueB1u8djybQcVJSV0Oluh9mac4GEUopresY0eYXfxUEPP5z1ttondto05oh_Ll0jRzb3HpcbaaLVj4jvGCz5Rckw57y0viFtAgxG2BXEfTL5SqNhKFRzRFmF105VGU2i1kl_gzwKYwxVoGGiSX5qI5Ejr-Dr3KdR4t1VN-ZQHUDG5-jz14_NfIPbKJJ0313Olj9jb4Mxjk9VzfUnUPMQMlSCWdzqn4YigKvWQfUqWG8OvQmn8gvMcabI6LEjQLixwPcuFIUjEPSTM3T_HGs3NV-UK4Ayy4WQ/file
# Reusing existing connection to uc19052472c037ffe11a72bed929.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13374071 (13M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/face_morpher.pt’
#
# data/models/separab 100%[===================>]  12.75M  13.5MB/s    in 0.9s
#
# 2024-09-21 20:50:45 (13.5 MB/s) - ‘data/models/separable_float/face_morpher.pt’ saved [13374071/13374071]
#
# --2024-09-21 20:50:45--  https://www.dropbox.com/s/8u0qond8po34l24/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/v0eb6dyk7kj8tphy8ycbq/two_algo_face_body_rotator.pt?rlkey=cihbim8nm1dzpdqnice3i8w6m&dl=0 [following]
# --2024-09-21 20:50:45--  https://www.dropbox.com/scl/fi/v0eb6dyk7kj8tphy8ycbq/two_algo_face_body_rotator.pt?rlkey=cihbim8nm1dzpdqnice3i8w6m&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com/cd/0/inline/CbAGKU9BjB9Fn8Ro1neUTpJM04XLgbua81NSk-EBKSl3Dp5O9jmuXOPttGrfXQW0ibToq3PDgGQZXkfU39LWQLyppVVKSWK3qAJ85HUwp57sjvGcle4FnIPOSB5elFuNbTQ/file# [following]
# --2024-09-21 20:50:46--  https://uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com/cd/0/inline/CbAGKU9BjB9Fn8Ro1neUTpJM04XLgbua81NSk-EBKSl3Dp5O9jmuXOPttGrfXQW0ibToq3PDgGQZXkfU39LWQLyppVVKSWK3qAJ85HUwp57sjvGcle4FnIPOSB5elFuNbTQ/file
# Resolving uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com (uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:6023:15::a27d:430f
# Connecting to uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com (uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbBTFw9QEdheooAZrcfaXDvbAyuWta5R61Nyp4yblqJ28EaSoGVDk1AxOWxgPLTkhnAAI9bpYRklBIB6gwlhCRkdyr4aCfoT4M7T6cd3wZTPWjo9fU3o8L59GtYhQLfiqIfmGJf6-_2atn7VBgBDpVBjLHHvFYiGsCJXJmE4Z2qscAz7OOpcMOWvWz4MEc5JlljDcaCUNKsNk1pdLj4-7vS2mfVCdi7kcAOYdwXfyMoGTf1adhNfJIRPVLKd8CPpzwLXFPZnyFsG8AIcd58cy5N1Z63Lynl2ozPyb3wZ_M9AnBgDhyk89N0ZiQdIO0lzXkG9MxSUo79K-_q52lFpEOCo3NYuNyQeQuRNS1ihohOLdA/file [following]
# --2024-09-21 20:50:48--  https://uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com/cd/0/inline2/CbBTFw9QEdheooAZrcfaXDvbAyuWta5R61Nyp4yblqJ28EaSoGVDk1AxOWxgPLTkhnAAI9bpYRklBIB6gwlhCRkdyr4aCfoT4M7T6cd3wZTPWjo9fU3o8L59GtYhQLfiqIfmGJf6-_2atn7VBgBDpVBjLHHvFYiGsCJXJmE4Z2qscAz7OOpcMOWvWz4MEc5JlljDcaCUNKsNk1pdLj4-7vS2mfVCdi7kcAOYdwXfyMoGTf1adhNfJIRPVLKd8CPpzwLXFPZnyFsG8AIcd58cy5N1Z63Lynl2ozPyb3wZ_M9AnBgDhyk89N0ZiQdIO0lzXkG9MxSUo79K-_q52lFpEOCo3NYuNyQeQuRNS1ihohOLdA/file
# Reusing existing connection to uc4ca3ff887b98cdef49fec5dd76.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14355239 (14M) [application/octet-stream]
# Saving to: ‘data/models/separable_float/two_algo_face_body_rotator.pt’
#
# data/models/separab 100%[===================>]  13.69M  5.49MB/s    in 2.5s
#
# 2024-09-21 20:50:51 (5.49 MB/s) - ‘data/models/separable_float/two_algo_face_body_rotator.pt’ saved [14355239/14355239]
#
# --2024-09-21 20:50:51--  https://www.dropbox.com/s/on8kn6z9fj95j0h/editor.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/c6kw58887mrtlestxyh1h/editor.pt?rlkey=kk35puvwaj35529ppaxlea8v9&dl=0 [following]
# --2024-09-21 20:50:52--  https://www.dropbox.com/scl/fi/c6kw58887mrtlestxyh1h/editor.pt?rlkey=kk35puvwaj35529ppaxlea8v9&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com/cd/0/inline/CbCoOWNO1eS3r2z9U658Ie9zOrMs1OwkrzYxnTvKIOaj9a58L5RN3_xDy9Q-dPlZOa4zC5rGyukTe_lthFxHF_28NA0lCP_2aknpH_oMULGVgEtyn8X2GLgJsExrjv8kn0E/file# [following]
# --2024-09-21 20:50:53--  https://ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com/cd/0/inline/CbCoOWNO1eS3r2z9U658Ie9zOrMs1OwkrzYxnTvKIOaj9a58L5RN3_xDy9Q-dPlZOa4zC5rGyukTe_lthFxHF_28NA0lCP_2aknpH_oMULGVgEtyn8X2GLgJsExrjv8kn0E/file
# Resolving ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com (ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6023:15::a27d:430f
# Connecting to ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com (ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbCUmXAuC5urTm5CES-G4i51br8uVuKlBILXERqb099nxEjdtlTxYCEEgkGncHSDpuig6wErVKz04Hurxab0Z-Qq3gk90DgT9GcXmWb7VcJxoFOya5e4dqX61e3YwIcdAl5PQkA1Df1mzv_ETsNnw7Dxv35Xe_RKWfq1rT_mqHrGlDesz8HCYiTKFgwGa0NC6uOP3UNd0mNpVRbbAB2mPmu-k55YIduP0VD9QXwB3YO7FQScaWXSly0eSh3HLVzlBtEDhtIchThpa6Mq5kR99A6f-F4WVw3-YRqM6K_MOnoY87Pav9q47dDCVqRjJW1H2gXiHeFUGRz8K_MDBo4WuIa9S7vKryHvLUTb1KKZnNmf9Q/file [following]
# --2024-09-21 20:50:53--  https://ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com/cd/0/inline2/CbCUmXAuC5urTm5CES-G4i51br8uVuKlBILXERqb099nxEjdtlTxYCEEgkGncHSDpuig6wErVKz04Hurxab0Z-Qq3gk90DgT9GcXmWb7VcJxoFOya5e4dqX61e3YwIcdAl5PQkA1Df1mzv_ETsNnw7Dxv35Xe_RKWfq1rT_mqHrGlDesz8HCYiTKFgwGa0NC6uOP3UNd0mNpVRbbAB2mPmu-k55YIduP0VD9QXwB3YO7FQScaWXSly0eSh3HLVzlBtEDhtIchThpa6Mq5kR99A6f-F4WVw3-YRqM6K_MOnoY87Pav9q47dDCVqRjJW1H2gXiHeFUGRz8K_MDBo4WuIa9S7vKryHvLUTb1KKZnNmf9Q/file
# Reusing existing connection to ucef6042c5f44136a68025fd6c9c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1918327 (1.8M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/editor.pt’
#
# data/models/separab 100%[===================>]   1.83M  --.-KB/s    in 0.09s
#
# 2024-09-21 20:50:54 (20.4 MB/s) - ‘data/models/separable_half/editor.pt’ saved [1918327/1918327]
#
# --2024-09-21 20:50:54--  https://www.dropbox.com/s/0hxu8opu1hmghqe/eyebrow_decomposer.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/npupclffia9t0h0l2ahc4/eyebrow_decomposer.pt?rlkey=ff7ytznb5n5mt6y3pebqlq19o&dl=0 [following]
# --2024-09-21 20:50:54--  https://www.dropbox.com/scl/fi/npupclffia9t0h0l2ahc4/eyebrow_decomposer.pt?rlkey=ff7ytznb5n5mt6y3pebqlq19o&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com/cd/0/inline/CbB_r__lmKTTXco65G-HqZlbj58O8vk-hjf-uyHAPBrEfZT2U-KzBWLf7bXTJQUs949OatXGdm_Bcl3SirDZ3bRgSxXxCxBSZ1YzOzsIOuaXcHngm-VAW6B9jhg30mmehec/file# [following]
# --2024-09-21 20:50:55--  https://ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com/cd/0/inline/CbB_r__lmKTTXco65G-HqZlbj58O8vk-hjf-uyHAPBrEfZT2U-KzBWLf7bXTJQUs949OatXGdm_Bcl3SirDZ3bRgSxXxCxBSZ1YzOzsIOuaXcHngm-VAW6B9jhg30mmehec/file
# Resolving ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com (ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com (ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbA3_phVtkqu7qwmt7JEpJq1hrU-IkF3oXc-9k8OdgBrgfDP5Pbirb5hKMc11-g1NKx7rO3-OpSkPIV0itTF5LObRMX0kTFknT26ivQgjxY6khf5YlrCw_eBosAeiXBk5XQf65mDj_EhlBv7iOoifkK5By98Rel6zrVT_FVGzI8HWbdQk58EWO06IHgE9LokMSg_4oy3YVyMeiPd-fxUjOQ63ZHWtyTWgb8iNZXbHaq3aBr6r4yEmZiVuRnzgFmt6bwYTeDxkqcHe8dclSq0Ekv_6Bdf2Wwos7EKurQqdx2BYLW0L_Gi9g7YZ5jfPCLQuZ7u9x8nCFW7cStjvuVZDZsKIh5ZXJ243iCDmYeKONQf-Q/file [following]
# --2024-09-21 20:50:55--  https://ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com/cd/0/inline2/CbA3_phVtkqu7qwmt7JEpJq1hrU-IkF3oXc-9k8OdgBrgfDP5Pbirb5hKMc11-g1NKx7rO3-OpSkPIV0itTF5LObRMX0kTFknT26ivQgjxY6khf5YlrCw_eBosAeiXBk5XQf65mDj_EhlBv7iOoifkK5By98Rel6zrVT_FVGzI8HWbdQk58EWO06IHgE9LokMSg_4oy3YVyMeiPd-fxUjOQ63ZHWtyTWgb8iNZXbHaq3aBr6r4yEmZiVuRnzgFmt6bwYTeDxkqcHe8dclSq0Ekv_6Bdf2Wwos7EKurQqdx2BYLW0L_Gi9g7YZ5jfPCLQuZ7u9x8nCFW7cStjvuVZDZsKIh5ZXJ243iCDmYeKONQf-Q/file
# Reusing existing connection to ucdec5b53c107eb4e9c913b96e02.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6673071 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/eyebrow_decomposer.pt’
#
# data/models/separab 100%[===================>]   6.36M  13.4MB/s    in 0.5s
#
# 2024-09-21 20:50:56 (13.4 MB/s) - ‘data/models/separable_half/eyebrow_decomposer.pt’ saved [6673071/6673071]
#
# --2024-09-21 20:50:56--  https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0 [following]
# --2024-09-21 20:50:57--  https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca74905718130609a1edeb53070.dl.dropboxusercontent.com/cd/0/inline/CbCQbJsIRN9Yjn-ZzJqpp_G1BisOZOPBPhl_Kfcd-KsfjZSN3S4bLsKzEFxsNZyyp_OYCclX3GgvH1adMsaDrCVt1DV0IUCCR6gzaRy0jeZFF_b0OitTlJfpirDoLIWfDKo/file# [following]
# --2024-09-21 20:50:58--  https://uca74905718130609a1edeb53070.dl.dropboxusercontent.com/cd/0/inline/CbCQbJsIRN9Yjn-ZzJqpp_G1BisOZOPBPhl_Kfcd-KsfjZSN3S4bLsKzEFxsNZyyp_OYCclX3GgvH1adMsaDrCVt1DV0IUCCR6gzaRy0jeZFF_b0OitTlJfpirDoLIWfDKo/file
# Resolving uca74905718130609a1edeb53070.dl.dropboxusercontent.com (uca74905718130609a1edeb53070.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uca74905718130609a1edeb53070.dl.dropboxusercontent.com (uca74905718130609a1edeb53070.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbBNxtAEvv5QzP2wCl5zKBHYmFppPzvOUmo7SqAZkBc46KkvIz8SbE3zVPB7_e8OmfyjzR2dE3i1tpYOYX0ZC_kqp945h91Q0HJ7n44uf2okGHWuLJ3K7hVoQhwsk-6q5jUai0D8FXgVw6igMRMDVwf_Q5m66DWvE_suk-o2NTWCoUZu2Dij4iaA0V8Yuhno21KV_nbA6H4XzsJy1nlfu3u1XJqo1YaKh1cE5sElOc9uZwPinvQX-HUv0PH9fMXFBN_QSWk0bmOZdEO8NiSOi9ILSi55jdUoK0Sj6tefFah7h6PEV3IOBW7oeu6sbmiZgrFBntabYpq1JClI8PSZwplyjH6JDrwZeZVN05fwhGO-wg/file [following]
# --2024-09-21 20:50:59--  https://uca74905718130609a1edeb53070.dl.dropboxusercontent.com/cd/0/inline2/CbBNxtAEvv5QzP2wCl5zKBHYmFppPzvOUmo7SqAZkBc46KkvIz8SbE3zVPB7_e8OmfyjzR2dE3i1tpYOYX0ZC_kqp945h91Q0HJ7n44uf2okGHWuLJ3K7hVoQhwsk-6q5jUai0D8FXgVw6igMRMDVwf_Q5m66DWvE_suk-o2NTWCoUZu2Dij4iaA0V8Yuhno21KV_nbA6H4XzsJy1nlfu3u1XJqo1YaKh1cE5sElOc9uZwPinvQX-HUv0PH9fMXFBN_QSWk0bmOZdEO8NiSOi9ILSi55jdUoK0Sj6tefFah7h6PEV3IOBW7oeu6sbmiZgrFBntabYpq1JClI8PSZwplyjH6JDrwZeZVN05fwhGO-wg/file
# Reusing existing connection to uca74905718130609a1edeb53070.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6683431 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/eyebrow_morphing_combiner.pt’
#
# data/models/separab 100%[===================>]   6.37M  21.8MB/s    in 0.3s
#
# 2024-09-21 20:51:00 (21.8 MB/s) - ‘data/models/separable_half/eyebrow_morphing_combiner.pt’ saved [6683431/6683431]
#
# --2024-09-21 20:51:00--  https://www.dropbox.com/s/bgz02afp0xojqfs/eyebrow_morphing_combiner.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0 [following]
# --2024-09-21 20:51:00--  https://www.dropbox.com/scl/fi/iaigcorfyl7tn3t4toa3s/eyebrow_morphing_combiner.pt?rlkey=xu3o925wiml52okq2ie73oiu0&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com/cd/0/inline/CbDoGeRl96EmCqTqFrVwBHjnYX5AMiXbwf3ssTzLBo0bQufmOlLvn8_AnriXD98DO_M5CwaJ1p9TT3bmn-kYFhkf70JOKUeEwD6vlKbQb33sqLHKL4l9ovg5kRrnNwpyxk0/file# [following]
# --2024-09-21 20:51:01--  https://uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com/cd/0/inline/CbDoGeRl96EmCqTqFrVwBHjnYX5AMiXbwf3ssTzLBo0bQufmOlLvn8_AnriXD98DO_M5CwaJ1p9TT3bmn-kYFhkf70JOKUeEwD6vlKbQb33sqLHKL4l9ovg5kRrnNwpyxk0/file
# Resolving uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com (uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com (uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbBF3Md2yXaOAViv0ReZUAsDe7olL0HaH0HrkRwuL70DxvsarYD1PKsbTOUvKmG7_2hoLEwdxYoXDMqep99XfvTA2TRXBi5zg61UZkdmWO18rlO6NzezF0Zf4bTpxsYoeQsfs37mKEivUWhsO1dMRi6K0GeiFqyEhwV4hwx5Ytx2msTznawN6px9TRWowDun3_8w46bQdZnaJ0ppzrj18Pc8wezB8Wluao_k0O-T5xlZyd7rWp5tcGoZK_6aCwC-lqw_1JECrlGTCCoym3at9pp6hs75W4Xb7-fy5-3awZUqz0da5VCwLZohv2zkEwcIzWZ2elC2dqAWdkG1dZi5l5hKCBZd8T22F16enwYz7NIGbw/file [following]
# --2024-09-21 20:51:02--  https://uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com/cd/0/inline2/CbBF3Md2yXaOAViv0ReZUAsDe7olL0HaH0HrkRwuL70DxvsarYD1PKsbTOUvKmG7_2hoLEwdxYoXDMqep99XfvTA2TRXBi5zg61UZkdmWO18rlO6NzezF0Zf4bTpxsYoeQsfs37mKEivUWhsO1dMRi6K0GeiFqyEhwV4hwx5Ytx2msTznawN6px9TRWowDun3_8w46bQdZnaJ0ppzrj18Pc8wezB8Wluao_k0O-T5xlZyd7rWp5tcGoZK_6aCwC-lqw_1JECrlGTCCoym3at9pp6hs75W4Xb7-fy5-3awZUqz0da5VCwLZohv2zkEwcIzWZ2elC2dqAWdkG1dZi5l5hKCBZd8T22F16enwYz7NIGbw/file
# Reusing existing connection to uc9c798e338d74dab08c21b50312.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6683431 (6.4M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/face_morpher.pt’
#
# data/models/separab 100%[===================>]   6.37M  3.16MB/s    in 2.0s
#
# 2024-09-21 20:51:05 (3.16 MB/s) - ‘data/models/separable_half/face_morpher.pt’ saved [6683431/6683431]
#
# --2024-09-21 20:51:05--  https://www.dropbox.com/s/vr8h2xxltszhw7w/two_algo_face_body_rotator.pt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/dzgcq5rddjujc5qe62wta/two_algo_face_body_rotator.pt?rlkey=mr1w82q23rs9vmt9tzv5qfdxz&dl=0 [following]
# --2024-09-21 20:51:05--  https://www.dropbox.com/scl/fi/dzgcq5rddjujc5qe62wta/two_algo_face_body_rotator.pt?rlkey=mr1w82q23rs9vmt9tzv5qfdxz&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com/cd/0/inline/CbDi8AyF4CDovaK-aEKQIcecMuYWbQWFekfDIWMR92CtDE1y0UTWRdttS5j4R55J9pYvJp_9pFKLJDCfv2SiF_Dnaws6iC0QbN3unrSOmIExYYHso7vSw0Jm74JM9rbYyjw/file# [following]
# --2024-09-21 20:51:06--  https://uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com/cd/0/inline/CbDi8AyF4CDovaK-aEKQIcecMuYWbQWFekfDIWMR92CtDE1y0UTWRdttS5j4R55J9pYvJp_9pFKLJDCfv2SiF_Dnaws6iC0QbN3unrSOmIExYYHso7vSw0Jm74JM9rbYyjw/file
# Resolving uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com (uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com (uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CbCBD5YrdDW94TxRMzKa7iFdB9pzkXERJYJoFm3ctz2HcNWKv5wMS-bri1_rslVXgOT7HFKfr_BOhMznnjApSRkanCeBD_5fCQPtIirxjksVrELgh1anu0GfNOo5YTgksZa-eipUxUYOAMPov4WiNTPJq_ojTt1trNTH8aJPt9XhHvO7OuMLyhvsehqY-u7n-HsyelRiw_ClhuWJje7UMtWCbc-4Nwr0AuE5B5CynYM5NZpEPLIlFH33fmiwoJSvIv56Ud-PIdQextS145GTLceoH-ZQPM-QPvLEZkACis42tCEtqIUqHu9YOAAUncfNu5RFD_MBePvZdBkVu1OsxMQP4zMMXQPrBvHlRtCh-hQKsg/file [following]
# --2024-09-21 20:51:08--  https://uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com/cd/0/inline2/CbCBD5YrdDW94TxRMzKa7iFdB9pzkXERJYJoFm3ctz2HcNWKv5wMS-bri1_rslVXgOT7HFKfr_BOhMznnjApSRkanCeBD_5fCQPtIirxjksVrELgh1anu0GfNOo5YTgksZa-eipUxUYOAMPov4WiNTPJq_ojTt1trNTH8aJPt9XhHvO7OuMLyhvsehqY-u7n-HsyelRiw_ClhuWJje7UMtWCbc-4Nwr0AuE5B5CynYM5NZpEPLIlFH33fmiwoJSvIv56Ud-PIdQextS145GTLceoH-ZQPM-QPvLEZkACis42tCEtqIUqHu9YOAAUncfNu5RFD_MBePvZdBkVu1OsxMQP4zMMXQPrBvHlRtCh-hQKsg/file
# Reusing existing connection to uca6a5c333c03efcd15843826798.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7195239 (6.9M) [application/octet-stream]
# Saving to: ‘data/models/separable_half/two_algo_face_body_rotator.pt’
#
# data/models/separab 100%[===================>]   6.86M  20.4MB/s    in 0.3s
#
# 2024-09-21 20:51:09 (20.4 MB/s) - ‘data/models/separable_half/two_algo_face_body_rotator.pt’ saved [7195239/7195239]

# %%
# Set this constant to specify which system variant to use.
MODEL_NAME = "standard_float"

# Load the models.
import torch
DEVICE_NAME = 'cuda'
device = torch.device(DEVICE_NAME)

def load_poser(model: str, device: torch.device):
    print("Using the %s model." % model)
    if model == "standard_float":
        from tha3.poser.modes.standard_float import create_poser
        return create_poser(device)
    elif model == "standard_half":
        from tha3.poser.modes.standard_half import create_poser
        return create_poser(device)
    elif model == "separable_float":
        from tha3.poser.modes.separable_float import create_poser
        return create_poser(device)
    elif model == "separable_half":
        from tha3.poser.modes.separable_half import create_poser
        return create_poser(device)
    else:
        raise RuntimeError("Invalid model: '%s'" % model)

poser = load_poser(MODEL_NAME, DEVICE_NAME)
poser.get_modules();
# Out:
# Using the standard_float model.
# Loading the eyebrow decomposer ...
# /content/talking-head-anime-3-demo/tha3/util.py:247: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f)
# DONE!!!
# Loading the eyebrow morphing conbiner ... DONE!!!
# Loading the face morpher ... DONE!!!
# Loading the face-body rotator ... DONE!!!
# Loading the combiner ... DONE!!!

# %%
# Create the GUI for manipulating character images.
import PIL.Image
import io
from io import StringIO, BytesIO
import IPython.display
import numpy
import ipywidgets
import time
import threading
import torch
from tha3.util import resize_PIL_image, extract_PIL_image_from_filelike, \
    extract_pytorch_image_from_PIL_image, convert_output_image_from_torch_to_numpy

FRAME_RATE = 30.0

last_torch_input_image = None
torch_input_image = None

def show_pytorch_image(pytorch_image):
    output_image = pytorch_image.detach().cpu()
    numpy_image = numpy.uint8(numpy.rint(convert_output_image_from_torch_to_numpy(output_image) * 255.0))
    pil_image = PIL.Image.fromarray(numpy_image, mode='RGBA')
    IPython.display.display(pil_image)

upload_input_image_button = ipywidgets.FileUpload(
    accept='.png',
    multiple=False,
    layout={
        'width': '512px'
    }
)

output_image_widget = ipywidgets.Output(
    layout={
        'border': '1px solid black',
        'width': '512px',
        'height': '512px'
    }
)

eyebrow_dropdown = ipywidgets.Dropdown(
    options=["troubled", "angry", "lowered", "raised", "happy", "serious"],
    value="troubled",
    description="Eyebrow:",
)
eyebrow_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eyebrow_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

eye_dropdown = ipywidgets.Dropdown(
    options=["wink", "happy_wink", "surprised", "relaxed", "unimpressed", "raised_lower_eyelid"],
    value="wink",
    description="Eye:",
)
eye_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
eye_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f"
)

mouth_dropdown = ipywidgets.Dropdown(
    options=["aaa", "iii", "uuu", "eee", "ooo", "delta", "lowered_corner", "raised_corner", "smirk"],
    value="aaa",
    description="Mouth:",
)
mouth_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Value:",
    readout=True,
    readout_format=".2f"
)
mouth_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description=" ",
    readout=True,
    readout_format=".2f",
    disabled=True,
)

def update_mouth_sliders(change):
    if mouth_dropdown.value == "lowered_corner" or mouth_dropdown.value == "raised_corner":
        mouth_left_slider.description = "Left:"
        mouth_right_slider.description = "Right:"
        mouth_right_slider.disabled = False
    else:
        mouth_left_slider.description = "Value:"
        mouth_right_slider.description = " "
        mouth_right_slider.disabled = True

mouth_dropdown.observe(update_mouth_sliders, names='value')

iris_small_left_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Left:",
    readout=True,
    readout_format=".2f"
)
iris_small_right_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Right:",
    readout=True,
    readout_format=".2f",
)
iris_rotation_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
iris_rotation_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",
)

head_x_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="X-axis:",
    readout=True,
    readout_format=".2f"
)
head_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis:",
    readout=True,
    readout_format=".2f",
)
neck_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis:",
    readout=True,
    readout_format=".2f",
)
body_y_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Y-axis rotation:",
    readout=True,
    readout_format=".2f",
)
body_z_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=-1.0,
    max=1.0,
    step=0.01,
    description="Z-axis rotation:",
    readout=True,
    readout_format=".2f",
)
breathing_slider = ipywidgets.FloatSlider(
    value=0.0,
    min=0.0,
    max=1.0,
    step=0.01,
    description="Breathing:",
    readout=True,
    readout_format=".2f",
)


control_panel = ipywidgets.VBox([
    eyebrow_dropdown,
    eyebrow_left_slider,
    eyebrow_right_slider,
    ipywidgets.HTML(value="<hr>"),
    eye_dropdown,
    eye_left_slider,
    eye_right_slider,
    ipywidgets.HTML(value="<hr>"),
    mouth_dropdown,
    mouth_left_slider,
    mouth_right_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Iris Shrinkage</b></center>"),
    iris_small_left_slider,
    iris_small_right_slider,
    ipywidgets.HTML(value="<center><b>Iris Rotation</b></center>"),
    iris_rotation_x_slider,
    iris_rotation_y_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Head Rotation</b></center>"),
    head_x_slider,
    head_y_slider,
    neck_z_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Body Rotation</b></center>"),
    body_y_slider,
    body_z_slider,
    ipywidgets.HTML(value="<hr>"),
    ipywidgets.HTML(value="<center><b>Breathing</b></center>"),
    breathing_slider,
])

controls = ipywidgets.HBox([
    ipywidgets.VBox([
        output_image_widget,
        upload_input_image_button
    ]),
    control_panel,
])

from tha3.poser.modes.pose_parameters import get_pose_parameters
pose_parameters = get_pose_parameters()
pose_size = poser.get_num_parameters()
last_pose = torch.zeros(1, pose_size, dtype=poser.get_dtype()).to(device)

iris_small_left_index = pose_parameters.get_parameter_index("iris_small_left")
iris_small_right_index = pose_parameters.get_parameter_index("iris_small_right")
iris_rotation_x_index = pose_parameters.get_parameter_index("iris_rotation_x")
iris_rotation_y_index = pose_parameters.get_parameter_index("iris_rotation_y")
head_x_index = pose_parameters.get_parameter_index("head_x")
head_y_index = pose_parameters.get_parameter_index("head_y")
neck_z_index = pose_parameters.get_parameter_index("neck_z")
body_y_index = pose_parameters.get_parameter_index("body_y")
body_z_index = pose_parameters.get_parameter_index("body_z")
breathing_index = pose_parameters.get_parameter_index("breathing")

def get_pose():
    pose = torch.zeros(1, pose_size, dtype=poser.get_dtype())

    eyebrow_name = f"eyebrow_{eyebrow_dropdown.value}"
    eyebrow_left_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_left")
    eyebrow_right_index = pose_parameters.get_parameter_index(f"{eyebrow_name}_right")
    pose[0, eyebrow_left_index] = eyebrow_left_slider.value
    pose[0, eyebrow_right_index] = eyebrow_right_slider.value

    eye_name = f"eye_{eye_dropdown.value}"
    eye_left_index = pose_parameters.get_parameter_index(f"{eye_name}_left")
    eye_right_index = pose_parameters.get_parameter_index(f"{eye_name}_right")
    pose[0, eye_left_index] = eye_left_slider.value
    pose[0, eye_right_index] = eye_right_slider.value

    mouth_name = f"mouth_{mouth_dropdown.value}"
    if mouth_name == "mouth_lowered_corner" or mouth_name == "mouth_raised_corner":
        mouth_left_index = pose_parameters.get_parameter_index(f"{mouth_name}_left")
        mouth_right_index = pose_parameters.get_parameter_index(f"{mouth_name}_right")
        pose[0, mouth_left_index] = mouth_left_slider.value
        pose[0, mouth_right_index] = mouth_right_slider.value
    else:
        mouth_index = pose_parameters.get_parameter_index(mouth_name)
        pose[0, mouth_index] = mouth_left_slider.value

    pose[0, iris_small_left_index] = iris_small_left_slider.value
    pose[0, iris_small_right_index] = iris_small_right_slider.value
    pose[0, iris_rotation_x_index] = iris_rotation_x_slider.value
    pose[0, iris_rotation_y_index] = iris_rotation_y_slider.value
    pose[0, head_x_index] = head_x_slider.value
    pose[0, head_y_index] = head_y_slider.value
    pose[0, neck_z_index] = neck_z_slider.value
    pose[0, body_y_index] = body_y_slider.value
    pose[0, body_z_index] = body_z_slider.value
    pose[0, breathing_index] = breathing_slider.value

    return pose.to(device)

display(controls)

def update(change):
    global last_pose
    global last_torch_input_image

    if torch_input_image is None:
        return

    needs_update = False
    if last_torch_input_image is None:
        needs_update = True
    else:
        if (torch_input_image - last_torch_input_image).abs().max().item() > 0:
            needs_update = True

    pose = get_pose()
    if (pose - last_pose).abs().max().item() > 0:
        needs_update = True

    if not needs_update:
        return

    output_image = poser.pose(torch_input_image, pose)[0]
    with output_image_widget:
        output_image_widget.clear_output(wait=True)
        show_pytorch_image(output_image)

    last_torch_input_image = torch_input_image
    last_pose = pose

def upload_image(change):
    global torch_input_image
    for name, file_info in upload_input_image_button.value.items():
        content = io.BytesIO(file_info['content'])
    if content is not None:
        pil_image = resize_PIL_image(extract_PIL_image_from_filelike(content), size=(512,512))
        w, h = pil_image.size
        if pil_image.mode != 'RGBA':
            with output_image_widget:
                torch_input_image = None
                output_image_widget.clear_output(wait=True)
                display(ipywidgets.HTML("Image must have an alpha channel!!!"))
        else:
            torch_input_image = extract_pytorch_image_from_PIL_image(pil_image).to(device)
            if poser.get_dtype() == torch.half:
                torch_input_image = torch_input_image.half()
        update(None)

upload_input_image_button.observe(upload_image, names='value')
eyebrow_dropdown.observe(update, 'value')
eyebrow_left_slider.observe(update, 'value')
eyebrow_right_slider.observe(update, 'value')
eye_dropdown.observe(update, 'value')
eye_left_slider.observe(update, 'value')
eye_right_slider.observe(update, 'value')
mouth_dropdown.observe(update, 'value')
mouth_left_slider.observe(update, 'value')
mouth_right_slider.observe(update, 'value')
iris_small_left_slider.observe(update, 'value')
iris_small_right_slider.observe(update, 'value')
iris_rotation_x_slider.observe(update, 'value')
iris_rotation_y_slider.observe(update, 'value')
head_x_slider.observe(update, 'value')
head_y_slider.observe(update, 'value')
neck_z_slider.observe(update, 'value')
body_y_slider.observe(update, 'value')
body_z_slider.observe(update, 'value')
breathing_slider.observe(update, 'value')
# Out:
# HTML(value='Image must have an alpha channel!!!')
